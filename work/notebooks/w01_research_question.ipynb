# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Jessicaayegh/Ml-notebook/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
# Refresh / Content Opportunity Scoring- ## 1. My lane (or freestyle) and why
#
# I am choosing the **Refresh / Content Opportunity Scoring** lane. I want to investigate how observable search, content, and engagement signals can be used to rank pages for human review. This lane fits my interest in machine learning because it allows me to start with a simple rule-based baseline and then test whether a machine-learning model can produce a better ranking.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
# ## 2. The question: decision, action, cost of a wrong call
#
# The decision I want to improve is which content pages should be reviewed first for possible improvement. A content or SEO team would use the ranked output to decide which pages to investigate and whether an appropriate action might be to refresh, expand, protect, prune, merge, or monitor a page. A false positive could waste limited editorial review time on a page that does not need attention, while a false negative could cause an important page or opportunity to be missed. Because the team has limited review capacity, the quality of the highest-ranked pages is more important than simply classifying every page correctly.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

url = "https://raw.githubusercontent.com/Jessicaayegh/Ml-notebook/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Number of rows:", len(df))
print("Number of unique content items:", df["content_id"].nunique())
print(
    "Percentage of pages with a declining trend:",
    round((df["trend_direction"] == "down").mean() * 100, 1),
)
# Out:
# Number of rows: 30000
# Number of unique content items: 30000
# Percentage of pages with a declining trend: 54.2

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# This project will make observed and directional claims based on the search, content, and engagement signals in the dataset. I can report patterns in the data and evaluate whether my scoring approach ranks pages for review better than a simple baseline. The final output will be decision-support for content teams, helping them prioritize pages for human review. I cannot claim that a recommended refresh will cause a page to recover, that the analysis proves a Google ranking factor, or that the model predicts Google's algorithm. The results will show associations and ranking performance in the available data, not causal effects.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
