# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Jessicaayegh/Ml-notebook/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
# I am framing my Refresh / Content Opportunity Scoring lane as a ranking problem. The goal is to rank content pages by their observed opportunity for refresh, so that a human reviewer can decide which pages should be reviewed first. The model would combine signals such as search performance, content characteristics, and engagement rather than relying on one fixed rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
# The target will be a proxy for content refresh opportunity, based on observable performance signals in the available data. I will not treat this proxy as a direct measure of future traffic or search-engine rankings. Instead, it will represent which pages appear more worthy of human review based on their measured performance and trends.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
# The main success metric will be ranking quality: whether the highest-ranked pages contain a larger share of pages that meet the defined refresh-opportunity criteria. I will compare the ML ranking with a simple fixed-rule baseline to see whether the model provides a more useful ordering for human review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
# The unit of analysis is one content page. Each row represents one unique content item, identified by content_id, with its associated search, content, engagement, and trend signals.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
# A fixed rule could identify declining pages using one or two signals, but it may miss combinations of signals that make some pages more important than others. An ML ranking approach can consider multiple observable features together and learn patterns from the available data. I will only claim that it can improve the prioritisation of pages for human review if the evaluation shows that it performs better than the baseline.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
